# %% [markdown]
# # 02 — Preprocessing
#
# Encodes categorical features, maps labels, scales numeric features, and saves the processed data.

# %%
import sys
sys.path.append('../')

import pandas as pd
import numpy as np
import joblib

from src.preprocess import preprocess, COLUMNS

# %% [markdown]
# ## Run Preprocessing Pipeline

# %%
data = preprocess('../NSLKDD/KDDTrain+.txt', '../NSLKDD/KDDTest+.txt')

X_train       = data['X_train']
X_test        = data['X_test']
y_train_bin   = data['y_train_bin']
y_test_bin    = data['y_test_bin']
y_train_multi = data['y_train_multi']
y_test_multi  = data['y_test_multi']
feature_cols  = data['feature_cols']

print(f'X_train: {X_train.shape}  X_test: {X_test.shape}')
print(f'Binary classes: {y_train_bin.value_counts().to_dict()}')
print(f'Multi classes:  {y_train_multi.value_counts().to_dict()}')
# Out:
# X_train: (125973, 41)  X_test: (22544, 41)
# Binary classes: {0: 67343, 1: 58630}
# Multi classes:  {'normal': 67343, 'DoS': 45927, 'Probe': 11656, 'R2L': 995, 'U2R': 52}

# %% [markdown]
# ## Inspect Encoded Features

# %%
df_check = pd.DataFrame(X_train, columns=feature_cols)
df_check.describe()
# Out:
#            duration  protocol_type       service          flag     src_bytes  \
# count  1.259730e+05   1.259730e+05  1.259730e+05  1.259730e+05  1.259730e+05
# mean   2.549477e-17  -6.196020e-17  6.407536e-17  8.387329e-17 -4.512349e-19
# std    1.000004e+00   1.000004e+00  1.000004e+00  1.000004e+00  1.000004e+00
# min   -1.102492e-01  -2.468724e+00 -1.910296e+00 -2.595417e+00 -7.762241e-03
# 25%   -1.102492e-01  -1.247062e-01 -6.867852e-01 -7.362346e-01 -7.762241e-03
# 50%   -1.102492e-01  -1.247062e-01 -4.420831e-01  7.511113e-01 -7.754745e-03
# 75%   -1.102492e-01  -1.247062e-01  1.087305e+00  7.511113e-01 -7.715224e-03
# max    1.636428e+01   2.219312e+00  2.310816e+00  1.122948e+00  2.350675e+02
#
#           dst_bytes          land  wrong_fragment        urgent           hot  \
# count  1.259730e+05  1.259730e+05    1.259730e+05  1.259730e+05  1.259730e+05
# mean   7.614590e-19 -4.794371e-18    4.230328e-19  4.455945e-18 -2.244894e-17
# ...

# %% [markdown]
# ## Save Preprocessed Data

# %%
import os
os.makedirs('../models', exist_ok=True)

joblib.dump(data, '../models/preprocessed_data.pkl')
print('Saved preprocessed data to ../models/preprocessed_data.pkl')
# Out:
# Saved preprocessed data to ../models/preprocessed_data.pkl
